# %% [markdown]
# # Pruebas algoritmos de clustering
#
# #### Inicialización de dataframes a trabajar

# %%
import pandas as pd

normal_BER = pd.read_csv("data/normal/BER.csv")
normal_IP = pd.read_csv("data/normal/InputPower.csv")
normal_OSNR = pd.read_csv("data/normal/OSNR.csv") 
anomaly_BER_filter = pd.read_csv("data/anomaly/filter/BER_Filtro.csv") 
anomaly_BER_iasen = pd.read_csv("data/anomaly/iasen/BER_IASEN.csv")
anomaly_OSNR_filter = pd.read_csv("data/anomaly/filter/OSNR_Filtro.csv") 
anomaly_OSNR_iasen = pd.read_csv("data/anomaly/iasen/OSNR_IASEN.csv")
anomaly_IP_filter = pd.read_csv("data/anomaly/filter/InputPower_Filtro.csv") 
anomaly_IP_iasen = pd.read_csv("data/anomaly/iasen/InputPower_IASEN.csv")

# %% [markdown]
# ### Graficando los datos:

# %%
import matplotlib.pyplot as plt

# valores = normal_BER.values.ravel()
valores = normal_BER.values.ravel()

tiempo = range(len(valores))

plt.figure(figsize=(8, 5))  # Tamaño de la figura
plt.plot(tiempo, valores, label='Valores')  # Línea con marcadores
plt.title("Gráfica de valores vs tiempo BER")
plt.xlabel("Tiempo")
plt.ylabel("Valores")
plt.grid(True)
plt.legend()
plt.show()
